# %%
import matplotlib

import matplotlib.font_manager as fm

font_location = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

font_name = fm.FontProperties(fname = font_location).get_name()

matplotlib.rc('font',family = font_name)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
dt1=pd.read_csv("product_data_01.csv", engine='python', header=1)
dt2=pd.read_csv("product_data_02.csv", engine='python', header=1)
dt3=pd.read_csv("product_data_03.csv", engine='python', header=1)
dt4=pd.read_csv("product_data_04.csv", engine='python', header=1)

# %%
dt4[(dt4.구매금액==0)&(dt4.구매수량==0)]
# Out:
#              공급일자        회원번호 조합원상태 물품대분류 물품중분류     물품소분류                물품명  \
# 1157   2018-01-08   555987072  정상회원    과실    과일        사과         사과/(2kg)/중
# 1183   2018-01-08   555987072  정상회원    과실    과일        사과         사과/(2kg)/중
# 1284   2018-01-08   555987072  정상회원    과실    과일        사과         사과/(2kg)/중
# 3766   2018-01-22    38808960  정상회원    채소  뿌리채소        울금           울금(500g)
# 3904   2018-01-23    64306688  정상회원    서류   고구마       고구마         황금고구마(1kg)
# 18984  2018-04-18  1394771008  정상회원    채소    버섯      목이버섯         목이버섯(200g)
# 24907  2018-05-24  1259964160  정상회원    간식     빵  식빵, 식사대용       쌀식빵(360g)/매장
# 40474  2018-08-20    86983296  정상회원   축산물   육가공  햄/소시지/훈제  불고기양념소시지(300g)-매장
# 42855  2018-09-03   469100288  정상회원   축산물   유제품    우유/산양유       우유(범산/200ml)
#
#        구매수량  구매금액 구매매장    반품_원거래일자   구매시각
# 1157    0.0     0  매장A  20180108.0  17:24
# 1183    0.0     0  매장A         NaN  17:50
# 1284    0.0     0  매장A  20180108.0  18:09
# ...

# %%
dt4[(dt4.구매금액!=0)&(dt4.구매수량==0)]
# Out:
# Empty DataFrame
# Columns: [공급일자, 회원번호, 조합원상태, 물품대분류, 물품중분류, 물품소분류, 물품명, 구매수량, 구매금액, 구매매장, 반품_원거래일자, 구매시각]
# Index: []

# %%
dt4_1 = dt4.copy()

# %%
dt4_1.head()
# Out:
#          공급일자       회원번호 조합원상태 물품대분류  물품중분류   물품소분류               물품명  구매수량  \
# 0  2018-01-02  220954944  정상회원    반찬  두부/유부      두부       두부(1모:420g)   1.0
# 1  2018-01-02   89023040  정상회원    채소   열매채소  단호박/손질    단호박(깍뚝썰기/300g)   1.0
# 2  2018-01-02  354941440  정상회원   축산물      알     유정란  유정란/매장용(10알/국내산)   1.0
# 3  2018-01-02  786634048    탈퇴    반찬   어묵/묵       묵     도토리묵(420g:1모)   1.0
# 4  2018-01-02  438543104  정상회원   축산물      알     유정란  유정란/매장용(10알/국내산)   1.0
#
#    구매금액 구매매장  반품_원거래일자   구매시각
# 0  3829  매장A       NaN  10:32
# 1  4977  매장A       NaN  10:41
# 2  7083  매장A       NaN  11:00
# 3  7083  매장A       NaN  11:28
# 4  7083  매장A       NaN  11:59

# %%
set(dt4[(dt4.구매금액==0)&(dt4.구매수량!=0)]['물품명'])
# Out:
# {'두부(반모:270g)/증정',
#  '새내기조합원물품할인권(파랑)',
#  '쌀 만난 반가米 증정품(사각휴지3상자)',
#  '에코백(증정)성남용인',
#  '자연그대로 아토크림(증정/15g)',
#  '조합원의식조사설문',
#  '중성세제 샘플(증정/100㎖)'}

# %% [markdown]
# # 두부 반모 증정에 반품 없음. 이상 없음.

# %%
dt4[dt4.물품명=='두부(반모:270g)/증정']
# Out:
#              공급일자        회원번호 조합원상태 물품대분류  물품중분류 물품소분류             물품명  구매수량  \
# 49929  2018-10-15   720900096  정상회원    반찬  두부/유부    두부  두부(반모:270g)/증정   1.0
# 50403  2018-10-17   905605504  정상회원    반찬  두부/유부    두부  두부(반모:270g)/증정   1.0
# 50951  2018-10-21  1167171584  정상회원    반찬  두부/유부    두부  두부(반모:270g)/증정   1.0
#
#        구매금액 구매매장  반품_원거래일자   구매시각
# 49929     0  매장A       NaN  10:11
# 50403     0  매장A       NaN  14:50
# 50951     0  매장A       NaN  16:01

# %% [markdown]
# # 새내기조합원물품할인권에 반품 없음. 이상 없음.

# %%
dt4[dt4.물품명=='새내기조합원물품할인권(파랑)']
# Out:
#              공급일자        회원번호 조합원상태 물품대분류 물품중분류 물품소분류              물품명  구매수량  \
# 43648  2018-09-07  1628704960  정상회원    기타   비물품   장려품  새내기조합원물품할인권(파랑)   1.0
#
#        구매금액 구매매장  반품_원거래일자   구매시각
# 43648     0  매장A       NaN  17:31

# %% [markdown]
# # 쌀 만난 반가米 증정품(사각휴지3상자)에 반품 없음. 이상 없음.

# %%
dt4[dt4.물품명=='쌀 만난 반가米 증정품(사각휴지3상자)']
# Out:
#              공급일자        회원번호 조합원상태 물품대분류 물품중분류 물품소분류                    물품명  \
# 19639  2018-04-21   410046080  정상회원    기타   비물품    기타  쌀 만난 반가米 증정품(사각휴지3상자)
# 20100  2018-04-24  1031948992  정상회원    기타   비물품    기타  쌀 만난 반가米 증정품(사각휴지3상자)
# 23319  2018-05-14   697514496  정상회원    기타   비물품    기타  쌀 만난 반가米 증정품(사각휴지3상자)
# 25421  2018-05-27  1328181440  정상회원    기타   비물품    기타  쌀 만난 반가米 증정품(사각휴지3상자)
# 29213  2018-06-19   757021568  정상회원    기타   비물품    기타  쌀 만난 반가米 증정품(사각휴지3상자)
# 31079  2018-06-29  1509135872  정상회원    기타   비물품    기타  쌀 만난 반가米 증정품(사각휴지3상자)
# 37503  2018-08-02  1398312256  정상회원    기타   비물품    기타  쌀 만난 반가米 증정품(사각휴지3상자)
# 42443  2018-08-31   365383296  정상회원    기타   비물품    기타  쌀 만난 반가米 증정품(사각휴지3상자)
# 43224  2018-09-05   115001472  정상회원    기타   비물품    기타  쌀 만난 반가米 증정품(사각휴지3상자)
# 43448  2018-09-06   405964736  정상회원    기타   비물품    기타  쌀 만난 반가米 증정품(사각휴지3상자)
# 44309  2018-09-11  1386109056  정상회원    기타   비물품    기타  쌀 만난 반가米 증정품(사각휴지3상자)
# ...

# %% [markdown]
# # 에코백(증정)성남용인에 반품 없음. 이상 없음.

# %%
dt4[dt4.물품명=='에코백(증정)성남용인']
# Out:
#              공급일자        회원번호 조합원상태 물품대분류 물품중분류 물품소분류          물품명  구매수량  \
# 16439  2018-04-04  1576610752  정상회원    기타   비물품   장려품  에코백(증정)성남용인   1.0
# 20235  2018-04-25  1582544384  정상회원    기타   비물품   장려품  에코백(증정)성남용인   1.0
# 20945  2018-04-30  1056303424  정상회원    기타   비물품   장려품  에코백(증정)성남용인   1.0
# 22286  2018-05-08  1583637568  정상회원    기타   비물품   장려품  에코백(증정)성남용인   1.0
# 22305  2018-05-08  1520836096  정상회원    기타   비물품   장려품  에코백(증정)성남용인   1.0
# 24246  2018-05-20  1580918528  정상회원    기타   비물품   장려품  에코백(증정)성남용인   1.0
#
#        구매금액 구매매장  반품_원거래일자   구매시각
# 16439     0  매장A       NaN  19:36
# 20235     0  매장A       NaN  16:27
# 20945     0  매장A       NaN  13:23
# 22286     0  매장A       NaN  17:26
# 22305     0  매장A       NaN  11:10
# 24246     0  매장A       NaN  13:27

# %% [markdown]
# # !!!!!!자연그대로 아토크림(증정/15g)에 반품 있음!!!!!!
# ## 증정인데 구매이력 없이 -1이 있음.

# %%
dt4[dt4.물품명=='자연그대로 아토크림(증정/15g)']
# Out:
#              공급일자        회원번호 조합원상태 물품대분류 물품중분류   물품소분류                 물품명  \
# 51033  2018-10-22   720900096  정상회원  생활용품   화장품  유아/썬크림  자연그대로 아토크림(증정/15g)
# 51037  2018-10-22   534398080  정상회원  생활용품   화장품  유아/썬크림  자연그대로 아토크림(증정/15g)
# 51069  2018-10-22   267093248  정상회원  생활용품   화장품  유아/썬크림  자연그대로 아토크림(증정/15g)
# 51106  2018-10-22  1040210048  정상회원  생활용품   화장품  유아/썬크림  자연그대로 아토크림(증정/15g)
# 51129  2018-10-22    42474560  정상회원  생활용품   화장품  유아/썬크림  자연그대로 아토크림(증정/15g)
# 51164  2018-10-23   967046528  정상회원  생활용품   화장품  유아/썬크림  자연그대로 아토크림(증정/15g)
# 51172  2018-10-23   514334720  정상회원  생활용품   화장품  유아/썬크림  자연그대로 아토크림(증정/15g)
# 51297  2018-10-23   275868416  정상회원  생활용품   화장품  유아/썬크림  자연그대로 아토크림(증정/15g)
# 51365  2018-10-24   876158208  정상회원  생활용품   화장품  유아/썬크림  자연그대로 아토크림(증정/15g)
# 51368  2018-10-24   251452736  정상회원  생활용품   화장품  유아/썬크림  자연그대로 아토크림(증정/15g)
# 51580  2018-10-25   747995840  정상회원  생활용품   화장품  유아/썬크림  자연그대로 아토크림(증정/15g)
# ...

# %% [markdown]
# #  조합원 의식 조사 설문에 반품 없음. 이상 없음.

# %%
dt4[dt4.물품명=='조합원의식조사설문']
# Out:
#              공급일자        회원번호 조합원상태 물품대분류 물품중분류 물품소분류        물품명  구매수량  구매금액  \
# 33412  2018-07-12  1212164736  정상회원    기타   비물품   장려품  조합원의식조사설문   1.0     0
# 33708  2018-07-14  1287462656  정상회원    기타   비물품   장려품  조합원의식조사설문   1.0     0
# 34293  2018-07-17   192994304  정상회원    기타   비물품   장려품  조합원의식조사설문   1.0     0
# 34300  2018-07-17   364626048  정상회원    기타   비물품   장려품  조합원의식조사설문   1.0     0
# 34435  2018-07-18   769460480  정상회원    기타   비물품   장려품  조합원의식조사설문   1.0     0
# 34496  2018-07-18  1352578560  정상회원    기타   비물품   장려품  조합원의식조사설문   1.0     0
# 34572  2018-07-19   728621056  정상회원    기타   비물품   장려품  조합원의식조사설문   1.0     0
# 34593  2018-07-19   728621056  정상회원    기타   비물품   장려품  조합원의식조사설문   1.0     0
# 35567  2018-07-23   357161216  정상회원    기타   비물품   장려품  조합원의식조사설문   1.0     0
# 36027  2018-07-24  1168363136  정상회원    기타   비물품   장려품  조합원의식조사설문   1.0     0
# 36351  2018-07-26  1009406016  정상회원    기타   비물품   장려품  조합원의식조사설문   1.0     0
#
#       구매매장  반품_원거래일자   구매시각
# ...

# %% [markdown]
# # 중성세제 샘플(증정/100㎖)에 반품 있음. 그러나 받은 기록 있음. 즉 이상 없음.

# %%
dt4[dt4.물품명=='중성세제 샘플(증정/100㎖)']
# Out:
#              공급일자        회원번호 조합원상태 물품대분류 물품중분류 물품소분류               물품명  구매수량  \
# 13679  2018-03-19   982122816  정상회원    기타   비물품    기타  중성세제 샘플(증정/100㎖)   1.0
# 13702  2018-03-19    20588608  정상회원    기타   비물품    기타  중성세제 샘플(증정/100㎖)   1.0
# 13733  2018-03-19   220954944  정상회원    기타   비물품    기타  중성세제 샘플(증정/100㎖)   1.0
# 13788  2018-03-20   234216064  정상회원    기타   비물품    기타  중성세제 샘플(증정/100㎖)   1.0
# 13889  2018-03-20  1464738496  정상회원    기타   비물품    기타  중성세제 샘플(증정/100㎖)   1.0
# 13923  2018-03-21  1201979008  정상회원    기타   비물품    기타  중성세제 샘플(증정/100㎖)   1.0
# 14146  2018-03-22  1298288704  정상회원    기타   비물품    기타  중성세제 샘플(증정/100㎖)   1.0
# 14256  2018-03-22   747104960  정상회원    기타   비물품    기타  중성세제 샘플(증정/100㎖)   1.0
# 14317  2018-03-23   768621568  정상회원    기타   비물품    기타  중성세제 샘플(증정/100㎖)   1.0
# 14322  2018-03-23   335202880  정상회원    기타   비물품    기타  중성세제 샘플(증정/100㎖)   1.0
# 14378  2018-03-23   743866240  정상회원    기타   비물품    기타  중성세제 샘플(증정/100㎖)   1.0
# ...

# %%
dt4[(dt4.회원번호==176912064)].head(50)
# Out:
#              공급일자       회원번호 조합원상태  물품대분류    물품중분류     물품소분류  \
# 13807  2018-03-20  176912064  정상회원     채소      콩나물       콩나물
# 14461  2018-03-23  176912064  정상회원  양념/가루  소스/기타양념      기타양념
# 14491  2018-03-23  176912064  정상회원     건강     건강일반    추출/농축액
# 15071  2018-03-27  176912064  정상회원     채소     양념채소        양파
# 15165  2018-03-27  176912064  정상회원    축산물      유제품    우유/산양유
# 15301  2018-03-28  176912064  정상회원     건강     건강일반    추출/농축액
# 15860  2018-03-31  176912064  정상회원  양념/가루  소스/기타양념      기타양념
# 16390  2018-04-04  176912064  정상회원     간식        빵     앙금크림빵
# 17474  2018-04-10  176912064  정상회원     간식        빵  식빵, 식사대용
# 17499  2018-04-10  176912064  정상회원     채소     열매채소        오이
# 17569  2018-04-10  176912064  정상회원     간식        떡       즉석떡
# 18548  2018-04-16  176912064  정상회원     간식        빵  식빵, 식사대용
# 18580  2018-04-16  176912064  정상회원     채소     양념채소        대파
# 18644  2018-04-16  176912064  정상회원   생활용품    세제/세안      세탁비누
# ...

# %%
dt4[(dt4.회원번호==176912064)].tail(50)
# Out:
#              공급일자       회원번호 조합원상태 물품대분류   물품중분류     물품소분류  \
# 31690  2018-07-03  176912064  정상회원  생활용품     화장품     기초화장품
# 31832  2018-07-03  176912064  정상회원  생활용품     화장품     기초화장품
# 34425  2018-07-18  176912064  정상회원    채소    쌈채소류       로메인
# 34509  2018-07-18  176912064  정상회원    채소  잎/줄기채소        부추
# 34830  2018-07-20  176912064  정상회원    수산    냉동수산      냉동생선
# 35151  2018-07-23  176912064  정상회원    채소    과일채소        참외
# 35478  2018-07-23  176912064  정상회원    잡곡  콩/화본/깨         콩
# 35799  2018-07-23  176912064  정상회원   축산물      돼지  보리살림(냉장)
# 36507  2018-07-27  176912064  정상회원    채소    열매채소        오이
# 37859  2018-08-04  176912064  정상회원    반찬   두부/유부        두부
# 38340  2018-08-07  176912064  정상회원    잡곡  보리/혼합곡        보리
# 38414  2018-08-08  176912064  정상회원   축산물     육가공  햄/소시지/훈제
# 38874  2018-08-10  176912064  정상회원    반찬    즉석조리      간편요리
# 39535  2018-08-15  176912064  정상회원   축산물      돼지  보리살림(냉장)
# 39830  2018-08-16  176912064  정상회원    채소    열매채소        가지
# ...

# %%
dt4[(dt4.회원번호==176912064) & (dt4.물품명=='흑토마토(1kg)')]
# Out:
#              공급일자       회원번호 조합원상태 물품대분류 물품중분류  물품소분류        물품명  구매수량   구매금액  \
# 25602  2018-05-28  176912064  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)  -1.0 -12444
#
#       구매매장    반품_원거래일자   구매시각
# 25602  매장A  20180528.0  15:01

# %%
dt4[(dt4.회원번호==176912064) & (dt4.물품소분류=='완숙토마토')]
# Out:
#              공급일자       회원번호 조합원상태 물품대분류 물품중분류  물품소분류        물품명  구매수량   구매금액  \
# 25602  2018-05-28  176912064  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)  -1.0 -12444
#
#       구매매장    반품_원거래일자   구매시각
# 25602  매장A  20180528.0  15:01

# %%
dt4[(dt4.구매금액!=0)&(dt4.구매수량==0)]
# Out:
# Empty DataFrame
# Columns: [공급일자, 회원번호, 조합원상태, 물품대분류, 물품중분류, 물품소분류, 물품명, 구매수량, 구매금액, 구매매장, 반품_원거래일자, 구매시각]
# Index: []

# %%
dt1[(dt1.회원번호==176912064) & (dt1.물품명=='흑토마토(1kg)')]
# Out:
# Empty DataFrame
# Columns: [공급일자, 회원번호, 조합원상태, 물품대분류, 물품중분류, 물품소분류, 물품명, 구매수량, 구매금액, 구매매장, 반품_원거래일자, 구매시각]
# Index: []

# %%
dt2[(dt2.회원번호==176912064) & (dt2.물품명=='흑토마토(1kg)')]
# Out:
# Empty DataFrame
# Columns: [공급일자, 회원번호, 조합원상태, 물품대분류, 물품중분류, 물품소분류, 물품명, 구매수량, 구매금액, 구매매장, 반품_원거래일자, 구매시각]
# Index: []

# %%
dt3[(dt3.회원번호==176912064) & (dt3.물품명=='흑토마토(1kg)')]
# Out:
# Empty DataFrame
# Columns: [공급일자, 회원번호, 조합원상태, 물품대분류, 물품중분류, 물품소분류, 물품명, 구매수량, 구매금액, 구매매장, 반품_원거래일자, 구매시각]
# Index: []

# %%
dt1[(dt1.회원번호==176912064)].tail(50)
# Out:
#               공급일자       회원번호 조합원상태  물품대분류    물품중분류     물품소분류  \
# 6094    2018-01-15  176912064  정상회원     건강     건강일반      분말/환
# 6172    2018-01-16  176912064  정상회원     반찬    두부/유부        두부
# 6401    2018-01-16  176912064  정상회원    축산물        알       유정란
# 7075    2018-01-18  176912064  정상회원    축산물     닭/오리     무항생제닭
# 8013    2018-01-20  176912064  정상회원     주곡       멥쌀        멥쌀
# 8125    2018-01-20  176912064  정상회원     간식      밀가공        국수
# 8395    2018-01-21  176912064  정상회원     음료        차       절임차
# 8496    2018-01-21  176912064  정상회원     음료       음료        과즙
# 10231   2018-01-25  176912064  정상회원    축산물        알       유정란
# 12289   2018-01-30  176912064  정상회원     간식        떡       즉석떡
# 12462   2018-01-30  176912064  정상회원     수산     생물수산    패류/갑각류
# 13036   2018-02-01  176912064  정상회원     수산       해조         김
# 14476   2018-02-05  176912064  정상회원     반찬    두부/유부        두부
# 14777   2018-02-05  176912064  정상회원  양념/가루        장     장류/기타
# ...

# %%
dt4[(dt4.물품명=='흑토마토(1kg)')]
# Out:
#              공급일자        회원번호 조합원상태 물품대분류 물품중분류  물품소분류        물품명  구매수량  \
# 24094  2018-05-19  1373627456  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 24903  2018-05-24   843273600  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 25436  2018-05-27  1386521088  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 25602  2018-05-28   176912064  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)  -1.0
# 27988  2018-06-11   110010688  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 28642  2018-06-15  1056303424  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 28769  2018-06-16   393343936  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 32807  2018-07-09   117226816  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 33482  2018-07-12  1558258624  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 34368  2018-07-17  1040081984  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 37335  2018-08-01   697514496  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 37645  2018-08-03   719977664  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# ...

# %%
dt1[(dt1.회원번호==176912064)].head(50)
# Out:
#              공급일자       회원번호 조합원상태  물품대분류    물품중분류     물품소분류  \
# 3      2018-01-02  176912064  정상회원    축산물      유제품    우유/산양유
# 68     2018-01-02  176912064  정상회원     채소   잎/줄기채소        배추
# 204    2018-01-02  176912064  정상회원    축산물   중량(정육)    한우(중량)
# 464    2018-01-02  176912064  정상회원     채소     과일채소        딸기
# 2831   2018-01-08  176912064  정상회원     수산     냉동수산    기타냉동수산
# 3464   2018-01-09  176912064  정상회원     반찬    두부/유부        두부
# 3863   2018-01-10  176912064  정상회원     수산     생물수산    패류/갑각류
# 4138   2018-01-11  176912064  정상회원    축산물      유제품    우유/산양유
# 4193   2018-01-11  176912064  정상회원     반찬    두부/유부        두부
# 4364   2018-01-11  176912064  정상회원    축산물   중량(정육)    한우(중량)
# 5751   2018-01-15  176912064  정상회원     간식        떡       가래떡
# 6094   2018-01-15  176912064  정상회원     건강     건강일반      분말/환
# 6172   2018-01-16  176912064  정상회원     반찬    두부/유부        두부
# 6401   2018-01-16  176912064  정상회원    축산물        알       유정란
# ...

# %%
dt1[(dt1.회원번호==176912064)].tail(50)
# Out:
#               공급일자       회원번호 조합원상태  물품대분류    물품중분류     물품소분류  \
# 6094    2018-01-15  176912064  정상회원     건강     건강일반      분말/환
# 6172    2018-01-16  176912064  정상회원     반찬    두부/유부        두부
# 6401    2018-01-16  176912064  정상회원    축산물        알       유정란
# 7075    2018-01-18  176912064  정상회원    축산물     닭/오리     무항생제닭
# 8013    2018-01-20  176912064  정상회원     주곡       멥쌀        멥쌀
# 8125    2018-01-20  176912064  정상회원     간식      밀가공        국수
# 8395    2018-01-21  176912064  정상회원     음료        차       절임차
# 8496    2018-01-21  176912064  정상회원     음료       음료        과즙
# 10231   2018-01-25  176912064  정상회원    축산물        알       유정란
# 12289   2018-01-30  176912064  정상회원     간식        떡       즉석떡
# 12462   2018-01-30  176912064  정상회원     수산     생물수산    패류/갑각류
# 13036   2018-02-01  176912064  정상회원     수산       해조         김
# 14476   2018-02-05  176912064  정상회원     반찬    두부/유부        두부
# 14777   2018-02-05  176912064  정상회원  양념/가루        장     장류/기타
# ...

# %%
dt2[(dt2.회원번호==176912064)]
# Out:
# Empty DataFrame
# Columns: [공급일자, 회원번호, 조합원상태, 물품대분류, 물품중분류, 물품소분류, 물품명, 구매수량, 구매금액, 구매매장, 반품_원거래일자, 구매시각]
# Index: []

# %%
dt3[(dt3.회원번호==176912064)]
# Out:
# Empty DataFrame
# Columns: [공급일자, 회원번호, 조합원상태, 물품대분류, 물품중분류, 물품소분류, 물품명, 구매수량, 구매금액, 구매매장, 반품_원거래일자, 구매시각]
# Index: []

# %%
dt4[dt4.물품명=='첫물차(30g)']
# Out:
#              공급일자       회원번호 조합원상태 물품대분류 물품중분류 물품소분류       물품명  구매수량   구매금액  \
# 48371  2018-10-04  176912064  정상회원    음료     차   잎꽃차  첫물차(30g)  -1.0 -51689
#
#       구매매장    반품_원거래일자   구매시각
# 48371  매장A  20181003.0  10:01

# %%
dt1[dt1.물품명=='첫물차(30g)']
# Out:
#              공급일자       회원번호 조합원상태 물품대분류 물품중분류 물품소분류       물품명  구매수량     구매금액  \
# 65089  2018-06-09  223390016  정상회원    음료     차   잎꽃차  첫물차(30g)   1.0  51689.0
#
#       구매매장  반품_원거래일자   구매시각
# 65089  매장C       NaN  12:23

# %%
dt1[dt1.물품명=='흑토마토(1kg)']
# Out:
#               공급일자        회원번호 조합원상태 물품대분류 물품중분류  물품소분류        물품명  구매수량  \
# 59852   2018-05-28   151568384  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 60120   2018-05-29   878194240  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 60455   2018-05-29   748561920  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 61704   2018-06-01   925639168  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 62534   2018-06-04   761604032  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 62906   2018-06-04    59011520  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 64112   2018-06-07  1211737856  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 65824   2018-06-11   769091136  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 66203   2018-06-12   326733952  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 67008   2018-06-15   273472320  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 68145   2018-06-18   428557824  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# 68269   2018-06-18  1112913280  정상회원    채소  과일채소  완숙토마토  흑토마토(1kg)   1.0
# ...

# %%
dt4_1.drop([25602, 51584], axis = 0, inplace = True)

# %%
dt4_1.loc[51513,'반품_원거래일자'] = 20181025

# %%
dt4_1.loc[51513,'반품_원거래일자']
# Out:
# 20181025.0

# %%
set(dt4['물품대분류'])
# Out:
# {'간식',
#  '건강',
#  '과실',
#  '기타',
#  '반찬',
#  '생활용품',
#  '서류',
#  '수산',
#  '양념/가루',
#  '음료',
#  '잡곡',
#  '주곡',
#  '주류',
#  '채소',
#  '축산물'}
